# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
# %ls
# Out:
#  磁碟區 C 中的磁碟是 Windows
#  磁碟區序號:  6632-9A6F
#
#  C:\Users\USER\Desktop\Jupyter Workspace\政大MOOC上課 的目錄
#
# 2020/02/18  下午 04:21    <DIR>          .
# 2020/02/18  下午 04:21    <DIR>          ..
# 2020/02/18  下午 04:21    <DIR>          .ipynb_checkpoints
# 2020/02/07  上午 10:14       211,942,105 raw_houses.csv
# 2020/02/18  下午 04:21                72 Untitled.ipynb
#                2 個檔案     211,942,177 位元組
#                3 個目錄  455,838,420,992 位元組可用

# %%
import panda as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-f542dbfa5144> in <module>
# ----> 1 import panda as pd
#
# ModuleNotFoundError: No module named 'panda'

# %%
import pandas as pd

# %%
pd.read_csv("raw_houses.csv")
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-5-3efc682f1eb9> in <module>
# ----> 1 pd.read_csv("raw_houses.csv")
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     683         )
#     684
# --> 685         return _read(filepath_or_buffer, kwds)
#     686
# ...

# %%
with open(file, 'r') as f:
        for str in f:
            # unicode 是python2里的，我在python3测试会有问题
            str = unicode(str, errors = 'replace')
            # or
            str = unicode(str, errors = 'ignore')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-c9e8a4a0b61b> in <module>
# ----> 1 with open(file, 'r') as f:
#       2         for str in f:
#       3             # unicode 是python2里的，我在python3测试会有问题
#       4             str = unicode(str, errors = 'replace')
#       5             # or
#
# NameError: name 'file' is not defined

# %%
with open("raw_houses.csv", 'r') as f:
        for str in f:
            # unicode 是python2里的，我在python3测试会有问题
            str = unicode(str, errors = 'replace')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-178cd2742573> in <module>
#       2         for str in f:
#       3             # unicode 是python2里的，我在python3测试会有问题
# ----> 4             str = unicode(str, errors = 'replace')
#
# NameError: name 'unicode' is not defined

# %%
import codecs

with codecs.open("raw_houses.csv", 'r', encoding='utf-8', 
        errors='ignore') as f:
    for str in f:
        # process
# Out:
#   File "<ipython-input-8-5559b27785bf>", line 6
#     # process
#              ^
# SyntaxError: unexpected EOF while parsing

# %%
import codecs

with codecs.open("raw_houses.csv", 'r', encoding='utf-8', 
        errors='ignore') as f:
    for str in f:
# Out:
#   File "<ipython-input-9-3d7186c33492>", line 5
#     for str in f:
#                  ^
# SyntaxError: unexpected EOF while parsing

# %%
df = pd.read_csv("raw_houses.csv", encoding = 'gb2312')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-10-fe07ec5bde73> in <module>
# ----> 1 df = pd.read_csv("raw_houses.csv", encoding = 'gb2312')
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     683         )
#     684
# ...

# %%
df = pd.read_csv("raw_houses.csv", encoding = 'gbk')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-11-2ac5dfec94c6> in <module>
# ----> 1 df = pd.read_csv("raw_houses.csv", encoding = 'gbk')
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     683         )
#     684
# ...

# %%
f_read=open('raw_houses.csv',encoding='gb2312')

# %%
pd.read_csv(f_read)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-13-4f6150b203bb> in <module>
# ----> 1 pd.read_csv(f_read)
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     683         )
#     684
# --> 685         return _read(filepath_or_buffer, kwds)
#     686
# ...

# %%
df = pd.read_csv('raw_houses.csv')

# %%
df.head(1)
# Out:
#         id 鄉鎮市區 交易標的   土地區段位置/建物區段門牌  土地移轉總面積(平方公尺) 使用分區或編定 非都市土地使用分區  \
# 0  2274694  中寮鄉   土地  先驅段1201~1230地號           73.0     NaN       鄉村區
#
#   非都市土地使用地    交易年月日  交易筆棟數_土地  ...  flag_debt_relation  flag_rush  \
# 0   乙種建築用地  1080725         2  ...                   f          f
#
#    flag_top_addition  flag_balcony_addition flag_flaw flag_presale  \
# 0                  f                      f         f            f
#
#   flag_relative_relation  flag_multiple_obligee  selected  flag_military_house
# 0                      f                      f         f                    f
#
# [1 rows x 65 columns]

# %%
df['交易標的'].value_counts()
# Out:
# 房地(土地+建物)       204643
# 房地(土地+建物)+車位    130117
# 土地              121894
# 車位                7512
# 建物                2527
# Name: 交易標的, dtype: int64

# %%
df.describe()
# Out:
#                  id  土地移轉總面積(平方公尺)         交易年月日       交易筆棟數_土地  \
# count  4.666930e+05   4.666930e+05  4.666930e+05  466693.000000
# mean   1.883759e+06   3.783251e+02  1.074312e+06       1.541446
# std    5.402777e+05   3.596537e+03  4.730789e+03       1.847697
# min    4.589900e+04   0.000000e+00  1.070101e+06       0.000000
# 25%    1.956435e+06   1.726000e+01  1.070526e+06       1.000000
# 50%    2.083619e+06   3.301000e+01  1.071018e+06       1.000000
# 75%    2.208329e+06   1.072400e+02  1.080320e+06       2.000000
# max    2.331293e+06   1.411456e+06  1.080915e+06     164.000000
#
#             交易筆棟數_建物       交易筆棟數_車位           移轉層次           總樓層數  \
# count  466693.000000  466693.000000  340367.000000  339811.000000
# mean        0.753090       0.360871       4.914096       9.762009
# std         0.653262       1.352548       5.268952       6.848465
# min         0.000000       0.000000     -13.000000      -2.000000
# ...

# %%
df[~(df['交易標的']=='土地')]
# Out:
#              id 鄉鎮市區       交易標的         土地區段位置/建物區段門牌  土地移轉總面積(平方公尺) 使用分區或編定  \
# 2       2274696  名間鄉  房地(土地+建物)        南投縣名間鄉武東巷1~30號         117.10     NaN
# 3       2274697  南投市  房地(土地+建物)    南投縣南投市祖祠路77巷31~60號          75.00       住
# 11      2257048  埔里鎮  房地(土地+建物)     南投縣埔里鎮蘭陽街36巷1~30號         124.90     NaN
# 13      2257049  埔里鎮  房地(土地+建物)     南投縣埔里鎮東榮路21巷1~30號          58.25       商
# 27      2256916  埔里鎮  房地(土地+建物)             AAAAAAAAa          95.57     NaN
# ...         ...  ...        ...                   ...            ...     ...
# 466682  2284561  仁武區  房地(土地+建物)    高雄市仁武區五和路16巷61~90號          88.03       住
# 466685  2284564  美濃區  房地(土地+建物)     高雄市美濃區廣興街511~540號          95.00       農
# 466688  2284567  茄萣區  房地(土地+建物)     高雄市茄萣區民權路241~270號          81.00       住
# 466690  2284569  茄萣區  房地(土地+建物)  高雄市茄萣區莒光路三段115巷1~30號         107.51       住
# 466691  2284570  湖內區  房地(土地+建物)  高雄市湖內區東方路105巷6弄1~30號          15.87       住
#
# ...

# %%
df[df['鄉鎮市區']=='內湖區']
# Out:
#              id 鄉鎮市區          交易標的             土地區段位置/建物區段門牌  土地移轉總面積(平方公尺)  \
# 75948   2254745  內湖區  房地(土地+建物)+車位       臺北市內湖區成功路二段361~390號          19.39
# 75952   2254493  內湖區  房地(土地+建物)+車位          臺北市內湖區安泰街91~120號          17.13
# 75954   2287694  內湖區     房地(土地+建物)        臺北市內湖區成功路三段91~120號          23.75
# 75963   2287930  內湖區     房地(土地+建物)         臺北市內湖區新明路151~180號          51.67
# 75964   2287931  內湖區     房地(土地+建物)      臺北市內湖區內湖路三段143巷1~30號          16.47
# ...         ...  ...           ...                       ...            ...
# 108784  2308248  內湖區  房地(土地+建物)+車位  臺北市內湖區民權東路六段180巷151~180號          23.30
# 108785  2308249  內湖區     房地(土地+建物)      臺北市內湖區民權東路六段121~150號           5.00
# 108837  2308306  內湖區     房地(土地+建物)         臺北市內湖區港墘路26巷1~30號          25.72
# 108838  2308307  內湖區  房地(土地+建物)+車位      臺北市內湖區民權東路六段181~210號          65.22
# 108839  2308308  內湖區     房地(土地+建物)        臺北市內湖區星雲街168巷1~30號          15.28
#
# ...

# %%
df[(df['交易標的']=='房地(土地+建物)') & (df['鄉鎮市區']=='內湖區')]
# Out:
#              id 鄉鎮市區       交易標的         土地區段位置/建物區段門牌  土地移轉總面積(平方公尺) 使用分區或編定  \
# 75954   2287694  內湖區  房地(土地+建物)    臺北市內湖區成功路三段91~120號          23.75       商
# 75963   2287930  內湖區  房地(土地+建物)     臺北市內湖區新明路151~180號          51.67       工
# 75964   2287931  內湖區  房地(土地+建物)  臺北市內湖區內湖路三段143巷1~30號          16.47       住
# 75975   2288151  內湖區  房地(土地+建物)   臺北市內湖區成功路四段181~210號          15.52      其他
# 76004   2306764  內湖區  房地(土地+建物)       臺北市內湖區安泰街61~90號          33.67       住
# ...         ...  ...        ...                   ...            ...     ...
# 108778  2308242  內湖區  房地(土地+建物)  臺北市內湖區成功路四段30巷31~60號          10.32       商
# 108779  2308243  內湖區  房地(土地+建物)        臺北市內湖區行善路1~30號          48.27       住
# 108785  2308249  內湖區  房地(土地+建物)  臺北市內湖區民權東路六段121~150號           5.00       商
# 108837  2308306  內湖區  房地(土地+建物)     臺北市內湖區港墘路26巷1~30號          25.72       住
# 108839  2308308  內湖區  房地(土地+建物)    臺北市內湖區星雲街168巷1~30號          15.28       住
#
# ...

# %%
df.iloc[27]['土地區段位置/建物區段門牌'] = 'AAAAAAAAa'
# Out:
# C:\Users\USER\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df.at[27,'土地區段位置/建物區段門牌'] = 'AAAAAAAAa'

# %%
df.[df['交易標的']=='土地' | &] = 42759865

# %%
df.head(100)
# Out:
#           id      鄉鎮市區       交易標的       土地區段位置/建物區段門牌  土地移轉總面積(平方公尺)  \
# 0   42759865  42759865   42759865            42759865     42759865.0
# 1   42759865  42759865   42759865            42759865     42759865.0
# 2    2274696       名間鄉  房地(土地+建物)      南投縣名間鄉武東巷1~30號          117.1
# 3    2274697       南投市  房地(土地+建物)  南投縣南投市祖祠路77巷31~60號           75.0
# 4   42759865  42759865   42759865            42759865     42759865.0
# ..       ...       ...        ...                 ...            ...
# 95  42759865  42759865   42759865            42759865     42759865.0
# 96  42759865  42759865   42759865            42759865     42759865.0
# 97  42759865  42759865   42759865            42759865     42759865.0
# 98  42759865  42759865   42759865            42759865     42759865.0
# 99   2256891       草屯鎮  房地(土地+建物)   南投縣草屯鎮玉屏路151~180號          117.0
#
#      使用分區或編定 非都市土地使用分區  非都市土地使用地     交易年月日  交易筆棟數_土地  ...  flag_debt_relation  \
# ...

# %%
df[df['鄉鎮市區']=='內湖*']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-abe74520c740> in <module>
# ----> 1 df[df['鄉鎮市區']=='內湖*']
#
# NameError: name 'df' is not defined

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-00cf07b74dcd> in <module>
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
df = pd.read_csv('raw_houses.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-4513b5e7e694> in <module>
# ----> 1 df = pd.read_csv('raw_houses.csv')
#
# NameError: name 'pd' is not defined

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
import pandas as pd

# %%
df = pd.read_csv('raw_houses.csv')
# Out:
# C:\Users\USER\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (6,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df
# Out:
#              id 鄉鎮市區       交易標的         土地區段位置/建物區段門牌  土地移轉總面積(平方公尺) 使用分區或編定  \
# 0       2274694  中寮鄉         土地        先驅段1201~1230地號          73.00     NaN
# 1       2274695  名間鄉         土地          吳厝段691~720地號         335.68       農
# 2       2274696  名間鄉  房地(土地+建物)        南投縣名間鄉武東巷1~30號         117.10     NaN
# 3       2274697  南投市  房地(土地+建物)    南投縣南投市祖祠路77巷31~60號          75.00       住
# 4       2274698  名間鄉         土地       南大庄段1111~1140地號          14.23       住
# ...         ...  ...        ...                   ...            ...     ...
# 466688  2284567  茄萣區  房地(土地+建物)     高雄市茄萣區民權路241~270號          81.00       住
# 466689  2284568  湖內區         土地       圍子內段3691~3720地號        5610.00     NaN
# 466690  2284569  茄萣區  房地(土地+建物)  高雄市茄萣區莒光路三段115巷1~30號         107.51       住
# 466691  2284570  湖內區  房地(土地+建物)  高雄市湖內區東方路105巷6弄1~30號          15.87       住
# 466692  2284571  路竹區         土地          文南段331~360地號         187.92       住
#
# ...

# %%
df[6,7]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: (6, 7)
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-5b843286ef7c> in <module>
# ----> 1 df[6,7]
#
# ...

# %%
df[df['鄉鎮市區']=='內湖區']
# Out:
#              id 鄉鎮市區          交易標的             土地區段位置/建物區段門牌  土地移轉總面積(平方公尺)  \
# 75948   2254745  內湖區  房地(土地+建物)+車位       臺北市內湖區成功路二段361~390號          19.39
# 75952   2254493  內湖區  房地(土地+建物)+車位          臺北市內湖區安泰街91~120號          17.13
# 75954   2287694  內湖區     房地(土地+建物)        臺北市內湖區成功路三段91~120號          23.75
# 75963   2287930  內湖區     房地(土地+建物)         臺北市內湖區新明路151~180號          51.67
# 75964   2287931  內湖區     房地(土地+建物)      臺北市內湖區內湖路三段143巷1~30號          16.47
# ...         ...  ...           ...                       ...            ...
# 108784  2308248  內湖區  房地(土地+建物)+車位  臺北市內湖區民權東路六段180巷151~180號          23.30
# 108785  2308249  內湖區     房地(土地+建物)      臺北市內湖區民權東路六段121~150號           5.00
# 108837  2308306  內湖區     房地(土地+建物)         臺北市內湖區港墘路26巷1~30號          25.72
# 108838  2308307  內湖區  房地(土地+建物)+車位      臺北市內湖區民權東路六段181~210號          65.22
# 108839  2308308  內湖區     房地(土地+建物)        臺北市內湖區星雲街168巷1~30號          15.28
#
# ...

# %%
'內湖' in df['鄉鎮市區']
# Out:
# False

# %%
keyword = "內湖"

# %%
keyword in df[]
# Out:
#   File "<ipython-input-14-5d0e23db96c2>", line 1
#     keyword in df[]
#                   ^
# SyntaxError: invalid syntax

# %%
df[df['鄉鎮市區' in keyword]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: False
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-0df93e6d08e9> in <module>
# ----> 1 df[df['鄉鎮市區' in keyword]]
#
# ...

# %%
df[df['鄉鎮市區' == keyword]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: False
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-b83bc2f0272f> in <module>
# ----> 1 df[df['鄉鎮市區' == keyword]]
#
# ...

# %%
df[df['鄉鎮市區'] == '內湖*']
# Out:
#   File "<ipython-input-22-9a06f5b4aa33>", line 1
#     df[df['鄉鎮市區'] == 內湖*]
#                         ^
# SyntaxError: invalid syntax

# %%
'內湖*' in df['鄉鎮市區'].values
# Out:
# False

# %%
df[1,2]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: (1, 2)
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-51-e14b1a40b4a7> in <module>
# ----> 1 df[1,2]
#
# ...

# %%
'內湖' is df['鄉鎮市區'].values
# Out:
# False

# %%
'建物' in df['交易標的']
# Out:
# False

# %%
'內湖.*' in df['鄉鎮市區'].values
# Out:
# False

# %%
df.head[10]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-1ce06cc519e4> in <module>
# ----> 1 df.head[10]
#
# TypeError: 'method' object is not subscriptable

# %%
df.head(10)
# Out:
#         id 鄉鎮市區       交易標的       土地區段位置/建物區段門牌  土地移轉總面積(平方公尺) 使用分區或編定  \
# 0  2274694  中寮鄉         土地      先驅段1201~1230地號          73.00     NaN
# 1  2274695  名間鄉         土地        吳厝段691~720地號         335.68       農
# 2  2274696  名間鄉  房地(土地+建物)      南投縣名間鄉武東巷1~30號         117.10     NaN
# 3  2274697  南投市  房地(土地+建物)  南投縣南投市祖祠路77巷31~60號          75.00       住
# 4  2274698  名間鄉         土地     南大庄段1111~1140地號          14.23       住
# 5  2274699  中寮鄉         土地        長安段331~360地號        3377.66     NaN
# 6  2314152  名間鄉         土地         北松嶺段61~90地號          18.11     NaN
# 7  2314153  名間鄉         土地         北松嶺段61~90地號         190.14     NaN
# 8  2314154  名間鄉         土地         北松嶺段61~90地號         192.97     NaN
# 9  2314208  名間鄉         土地       出林虎段391~420地號         230.62     NaN
#
#   非都市土地使用分區 非都市土地使用地    交易年月日  交易筆棟數_土地  ...  flag_debt_relation  flag_rush  \
# 0       鄉村區   乙種建築用地  1080725         2  ...                   f          f
# ...

# %%
df[,2]
# Out:
#   File "<ipython-input-31-1b4901d28fb2>", line 1
#     df[,2]
#        ^
# SyntaxError: invalid syntax

# %%
df[:2]
# Out:
#         id 鄉鎮市區 交易標的   土地區段位置/建物區段門牌  土地移轉總面積(平方公尺) 使用分區或編定 非都市土地使用分區  \
# 0  2274694  中寮鄉   土地  先驅段1201~1230地號          73.00     NaN       鄉村區
# 1  2274695  名間鄉   土地    吳厝段691~720地號         335.68       農       NaN
#
#   非都市土地使用地    交易年月日  交易筆棟數_土地  ...  flag_debt_relation  flag_rush  \
# 0   乙種建築用地  1080725         2  ...                   f          f
# 1      NaN  1080623         5  ...                   f          f
#
#    flag_top_addition  flag_balcony_addition flag_flaw flag_presale  \
# 0                  f                      f         f            f
# 1                  f                      f         f            f
#
#   flag_relative_relation  flag_multiple_obligee  selected  flag_military_house
# 0                      f                      f         f                    f
# 1                      f                      f         f                    f
#
# [2 rows x 65 columns]

# %%
df['交易標的']
# Out:
# 0                土地
# 1                土地
# 2         房地(土地+建物)
# 3         房地(土地+建物)
# 4                土地
#             ...
# 466688    房地(土地+建物)
# 466689           土地
# 466690    房地(土地+建物)
# 466691    房地(土地+建物)
# 466692           土地
# Name: 交易標的, Length: 466693, dtype: object

# %%
'建物' in df['交易標的']
# Out:
# False

# %%
'*建物*' in df['交易標的']
# Out:
# False

# %%
keyword ='建物'

# %%
message ='房地(土地+建物)'

# %%
keyword in message
# Out:
# True

# %%
keyword in df[]
# Out:
#   File "<ipython-input-39-5d0e23db96c2>", line 1
#     keyword in df[]
#                   ^
# SyntaxError: invalid syntax

# %%
keyword in df['交易標的']
# Out:
# False

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-44-8625ffd08463> in <module>
# ----> 1 '內湖區' is df['鄉鎮市區'].value
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'value'

# %%
'內湖區' is df['鄉鎮市區']
# Out:
# False

# %%
df.head(20)
# Out:
#          id 鄉鎮市區       交易標的       土地區段位置/建物區段門牌  土地移轉總面積(平方公尺) 使用分區或編定  \
# 0   2274694  中寮鄉         土地      先驅段1201~1230地號          73.00     NaN
# 1   2274695  名間鄉         土地        吳厝段691~720地號         335.68       農
# 2   2274696  名間鄉  房地(土地+建物)      南投縣名間鄉武東巷1~30號         117.10     NaN
# 3   2274697  南投市  房地(土地+建物)  南投縣南投市祖祠路77巷31~60號          75.00       住
# 4   2274698  名間鄉         土地     南大庄段1111~1140地號          14.23       住
# 5   2274699  中寮鄉         土地        長安段331~360地號        3377.66     NaN
# 6   2314152  名間鄉         土地         北松嶺段61~90地號          18.11     NaN
# 7   2314153  名間鄉         土地         北松嶺段61~90地號         190.14     NaN
# 8   2314154  名間鄉         土地         北松嶺段61~90地號         192.97     NaN
# 9   2314208  名間鄉         土地       出林虎段391~420地號         230.62     NaN
# 10  2314209  名間鄉         土地       南田子段781~810地號          69.47     NaN
# 11  2257048  埔里鎮  房地(土地+建物)   南投縣埔里鎮蘭陽街36巷1~30號         124.90     NaN
# ...

# %%
arr = np.array(df.head[10])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-52-2f44f773f109> in <module>
# ----> 1 arr = np.array(df.head[10])
#
# TypeError: 'method' object is not subscriptable

# %%
df
# Out:
#              id 鄉鎮市區       交易標的         土地區段位置/建物區段門牌  土地移轉總面積(平方公尺) 使用分區或編定  \
# 0       2274694  中寮鄉         土地        先驅段1201~1230地號          73.00     NaN
# 1       2274695  名間鄉         土地          吳厝段691~720地號         335.68       農
# 2       2274696  名間鄉  房地(土地+建物)        南投縣名間鄉武東巷1~30號         117.10     NaN
# 3       2274697  南投市  房地(土地+建物)    南投縣南投市祖祠路77巷31~60號          75.00       住
# 4       2274698  名間鄉         土地       南大庄段1111~1140地號          14.23       住
# ...         ...  ...        ...                   ...            ...     ...
# 466688  2284567  茄萣區  房地(土地+建物)     高雄市茄萣區民權路241~270號          81.00       住
# 466689  2284568  湖內區         土地       圍子內段3691~3720地號        5610.00     NaN
# 466690  2284569  茄萣區  房地(土地+建物)  高雄市茄萣區莒光路三段115巷1~30號         107.51       住
# 466691  2284570  湖內區  房地(土地+建物)  高雄市湖內區東方路105巷6弄1~30號          15.87       住
# 466692  2284571  路竹區         土地          文南段331~360地號         187.92       住
#
# ...

# %%
df = df.values

# %%
df
# Out:
# array([[2274694, '中寮鄉', '土地', ..., 'f', 'f', 'f'],
#        [2274695, '名間鄉', '土地', ..., 'f', 'f', 'f'],
#        [2274696, '名間鄉', '房地(土地+建物)', ..., 'f', 'f', 'f'],
#        ...,
#        [2284569, '茄萣區', '房地(土地+建物)', ..., 'f', 'f', 'f'],
#        [2284570, '湖內區', '房地(土地+建物)', ..., 'f', 'f', 'f'],
#        [2284571, '路竹區', '土地', ..., 'f', 'f', 'f']], dtype=object)

# %%
print(df[ : , 2])
# Out:
# ['土地' '土地' '房地(土地+建物)' ... '房地(土地+建物)' '房地(土地+建物)' '土地']

# %%
print(keyword in df[ : , 2])
# Out:
# True

# %%
for i in range(1,10):
    if ('土地' in df[i,2]) & ('建物' in df[i,2]):
        print(df[i,])
# Out:
# [2274696 '名間鄉' '房地(土地+建物)' '南投縣名間鄉武東巷1~30號' 117.1 nan '鄉村區' '乙種建築用地'
#  1080725 1 1 0 0.0 2.0 '透天厝' '住商用' '加強磚造' 810707.0 126.72 3 1 2 't' 'f'
#  1700000 13415.0 nan 0.0 0 214890 2639447 'f' 27.06575342
#  'RPRNMLNKQHOFFAM56CA' nan 23.85896711 120.6552861
#  '0101000020E61000005FC63235F0295E40726ABD44E5DB3740' '南投縣名間鄉' '南投縣'
#  '54:05.1' '54:05.1' '大坑村' nan nan 2094083
#  'e8f005a14db2aa6b1b4b1349c03f1d6a1330b4812784ca522ee1c9bfe8dc0a05' 'f'
#  'f' 'f' 'f' 'f' 'f' 'f' 'f' 'f' 'f' 'f' 'f' 'f' 'f' 'f' 'f' 'f' 'f']
# [2274697 '南投市' '房地(土地+建物)' '南投縣南投市祖祠路77巷31~60號' 75.0 '住' nan nan 1080703 1
#  1 0 0.0 2.0 '透天厝' '住商用' '鋼筋混凝土加強磚造' 751028.0 85.87 4 2 4 't' 'f' 6700000
#  78025.0 nan 0.0 0 118463 2645169 'f' 32.70136986 'RPWNMLMLQHOFFAM07CA'
#  nan 23.90559428 119.7081611
#  '0101000020E6100000A6EFBF8252ED5D4048AEDF06D5E73740' '南投縣名間鄉' '南投縣'
#  '54:05.3' '54:05.3' '三崙村' '祖祠路' nan 2094084
#  '5dc20bd0f7dae4418a549109d01c0bab1cb58b3fb94778d60f8ce30c1352bbba' 'f'
# ...

# %%
print(df[1,3])
# Out:
# 吳厝段691~720地號

# %%
print(df[2,2])
# Out:
# 房地(土地+建物)

# %%
df[2,2] == "*建物*"
# Out:
# False

# %%
x

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('raw_houses.csv')

# %%
df[(df['交易標的'].str.contains('建物')) | (df['交易標的'].str.contains('土地'))]
# Out:
#              id 鄉鎮市區       交易標的         土地區段位置/建物區段門牌  土地移轉總面積(平方公尺) 使用分區或編定  \
# 0       2274694  中寮鄉         土地        先驅段1201~1230地號          73.00     NaN
# 1       2274695  名間鄉         土地          吳厝段691~720地號         335.68       農
# 2       2274696  名間鄉  房地(土地+建物)        南投縣名間鄉武東巷1~30號         117.10     NaN
# 3       2274697  南投市  房地(土地+建物)    南投縣南投市祖祠路77巷31~60號          75.00       住
# 4       2274698  名間鄉         土地       南大庄段1111~1140地號          14.23       住
# ...         ...  ...        ...                   ...            ...     ...
# 466688  2284567  茄萣區  房地(土地+建物)     高雄市茄萣區民權路241~270號          81.00       住
# 466689  2284568  湖內區         土地       圍子內段3691~3720地號        5610.00     NaN
# 466690  2284569  茄萣區  房地(土地+建物)  高雄市茄萣區莒光路三段115巷1~30號         107.51       住
# 466691  2284570  湖內區  房地(土地+建物)  高雄市湖內區東方路105巷6弄1~30號          15.87       住
# 466692  2284571  路竹區         土地          文南段331~360地號         187.92       住
#
# ...

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('raw_houses.csv')
# Out:
# C:\Users\USER\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (6,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
毛胚屋 = df[(df['備註'].str.contains('毛胚')) | (df['備註'].str.contains('無*隔間')) | (df['備註'].str.contains('房間需自行隔間'))]

# %%
((df['備註'].str.contains('毛胚')) | (df['備註'].str.contains('無*隔間')) | (df['備註'].str.contains('房間需自行隔間'))).value_counts()
# Out:
# False    466141
# True        552
# Name: 備註, dtype: int64

# %%
毛胚屋.describe()
# Out:
#                  id  土地移轉總面積(平方公尺)         交易年月日    交易筆棟數_土地    交易筆棟數_建物  \
# count  5.520000e+02     552.000000  5.520000e+02  552.000000  552.000000
# mean   2.001386e+06     109.581033  1.074523e+06    1.494565    1.137681
# std    3.591148e+05     559.302823  4.739668e+03    0.845597    0.648237
# min    3.632090e+05       0.000000  1.070102e+06    0.000000    0.000000
# 25%    1.990834e+06      19.480000  1.070712e+06    1.000000    1.000000
# 50%    2.107800e+06      26.740000  1.071107e+06    1.000000    1.000000
# 75%    2.212169e+06      52.002500  1.080328e+06    2.000000    1.000000
# max    2.329589e+06    9925.340000  1.080821e+06    4.000000    8.000000
#
#          交易筆棟數_車位        移轉層次        總樓層數        建築完成年月  建物移轉總面積(平方公尺)  ...  \
# count  552.000000  551.000000  551.000000  5.360000e+02     552.000000  ...
# mean     0.981884    7.753176   13.651543  9.818481e+05     287.890616  ...
# std      1.094300    7.294136    9.304847  1.338148e+05     415.211006  ...
# ...

# %%
公共設施保留地之交易 =  df[(df['備註'].str.contains('公設')) | (df['備註'].str.contains('公保地')) | (df['備註'].str.contains('公共設施保留地')) | ~(df['備註'].str.contains('公設')) | (df['備註'].str.contains('公保地')) | (df['備註'].str.contains('公共設施保留地')) ]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-94e2f3adc434> in <module>
# ----> 1 公共設施保留地之交易 =  df[(df['備註'].str.contains('公設')) | (df['備註'].str.contains('公保地')) | (df['備註'].str.contains('公共設施保留地')) | ~(df['備註'].str.contains('公設')) | (df['備註'].str.contains('公保地')) | (df['備註'].str.contains('公共設施保留地')) ]
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __invert__(self)
#    1539     def __invert__(self):
#    1540         try:
# -> 1541             arr = operator.inv(com.values_from_object(self))
#    1542             return self.__array_wrap__(arr)
#    1543         except Exception:
#
# TypeError: bad operand type for unary ~: 'float'

# %%
公共設施保留地之交易 =  df[(df['備註'].str.contains('公設')) | (df['備註'].str.contains('公保地')) | \
                           (df['備註'].str.contains('公共設施保留地')) | (~df['備註'].str.contains('獨立產權公設'))  ]

# %%
df['備註'] = df['備註'].fillna('')

# %%
df[(~df['備註'].str.contains('獨立產權公設', regex=False))]
# Out:
#              id 鄉鎮市區       交易標的         土地區段位置/建物區段門牌  土地移轉總面積(平方公尺) 使用分區或編定  \
# 0       2274694  中寮鄉         土地        先驅段1201~1230地號          73.00     NaN
# 1       2274695  名間鄉         土地          吳厝段691~720地號         335.68       農
# 2       2274696  名間鄉  房地(土地+建物)        南投縣名間鄉武東巷1~30號         117.10     NaN
# 3       2274697  南投市  房地(土地+建物)    南投縣南投市祖祠路77巷31~60號          75.00       住
# 4       2274698  名間鄉         土地       南大庄段1111~1140地號          14.23       住
# ...         ...  ...        ...                   ...            ...     ...
# 466688  2284567  茄萣區  房地(土地+建物)     高雄市茄萣區民權路241~270號          81.00       住
# 466689  2284568  湖內區         土地       圍子內段3691~3720地號        5610.00     NaN
# 466690  2284569  茄萣區  房地(土地+建物)  高雄市茄萣區莒光路三段115巷1~30號         107.51       住
# 466691  2284570  湖內區  房地(土地+建物)  高雄市湖內區東方路105巷6弄1~30號          15.87       住
# 466692  2284571  路竹區         土地          文南段331~360地號         187.92       住
#
# ...

# %%
公共設施保留地之交易
# Out:
#              id 鄉鎮市區 交易標的         土地區段位置/建物區段門牌  土地移轉總面積(平方公尺) 使用分區或編定  \
# 188      604087  水里鄉   土地        城中段1141~1170地號         412.88      其他
# 856      604959  南投市   土地          永新段181~210地號         132.22       住
# 1226     605368  國姓鄉   土地          石門段931~960地號        1769.70       住
# 1303     605449  南投市   土地         茄苳腳段241~270地號          92.00       住
# 1318     605465  集集鎮   土地        林興段1021~1050地號         467.75       農
# ...         ...  ...  ...                   ...            ...     ...
# 466351  2320768  林園區   土地  王公廟段苦苓腳小段1201~1230地號           6.69       住
# 466353  2320770  大寮區   土地        大寮段2341~2370地號        1020.00       農
# 466597  2321014  鳳山區   土地        埤頂段2131~2160地號         450.55      其他
# 466615  2321034  湖內區   土地        海埔段2941~2970地號         732.00      其他
# 466679  2284558  鳥松區   土地        鳳松段1081~1110地號         267.52      其他
#
#        非都市土地使用分區 非都市土地使用地    交易年月日  交易筆棟數_土地  ...  flag_debt_relation  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 466693 entries, 0 to 466692
# Data columns (total 65 columns):
# id                              466693 non-null int64
# 鄉鎮市區                            466693 non-null object
# 交易標的                            466693 non-null object
# 土地區段位置/建物區段門牌                   466693 non-null object
# 土地移轉總面積(平方公尺)                   466693 non-null float64
# 使用分區或編定                         372425 non-null object
# 非都市土地使用分區                       89654 non-null object
# 非都市土地使用地                        89280 non-null object
# 交易年月日                           466693 non-null int64
# 交易筆棟數_土地                        466693 non-null int64
# 交易筆棟數_建物                        466693 non-null int64
# 交易筆棟數_車位                        466693 non-null int64
# 移轉層次                            340367 non-null float64
# 總樓層數                            339811 non-null float64
# 建物型態                            466693 non-null object
# ...

# %%
u_group2 = df[(df['備註'].str.contains('瑕疵物件')) | (df['備註'].str.contains('受損房屋')) | (df['備註'].str.contains('老舊')) | (df['備註'].str.contains('凶宅')) | (df['備註'].str.contains('祭祀公業')) | (df['備註'].str.contains('事故')) | (df['備註'].str.contains('非自然')) | (df['備註'].str.contains('無接水電')) | (df['備註'].str.contains('損壞')) | df['備註'].str.contains('破損')) | (df['備註'].str.contains('滲*水')) | (df['備註'].str.contains('壁癌')) | (df['備註'].str.contains('屋況不佳')) | (df['備註'].str.contains('屋況*差')) | (df['備註'].str.contains('屋況嚴重瑕疵')) | (df['備註'].str.contains('房屋*半毀')) | (df['備註'].str.contains('房屋破舊')) | (df['備註'].str.contains('屋況需整理')) | (df['備註'].str.contains('屋況殘破')) | (df['備註'].str.contains('屋況不良')) | (df['備註'].str.contains('房屋*已坍塌')) | (df['備註'].str.contains('臨近殯儀館')) | (df['備註'].str.contains('房屋老舊')) | (df['備註'].str.contains('建物須整修')) | (df['備註'].str.contains('入口處狹小巷弄狹小')) | (df['備註'].str.contains('無接水接電')) | (df['備註'].str.contains('高壓電線正下方')) | df['備註'].str.contains('多年無人使用')) | (df['備註'].str.contains('建物已毀損')) | (df['備註'].str.contains('壁癌')) | (df['備註'].str.contains('屋況不佳')) | (df['備註'].str.contains('屋況*差')) | (df['備註'].str.contains('死亡')) | (df['備註'].str.contains('年久失修')) | (df['備註'].str.contains('房屋破舊')) | (df['備註'].str.contains('廢墟')) | (df['備註'].str.contains('面積流失')) | (df['備註'].str.contains('荒廢')) | (df['備註'].str.contains('河床侵蝕')) | (df['備註'].str.contains('無法居住'))]
# Out:
#   File "<ipython-input-57-81fc6d572e75>", line 1
# ...

# %%
df[(df['備註'].str.contains('瑕疵物件')) | (df['備註'].str.contains('受損房屋')) | (df['備註'].str.contains('老舊')) | (df['備註'].str.contains('凶宅')) | (df['備註'].str.contains('祭祀公業')) | (df['備註'].str.contains('事故')) | (df['備註'].str.contains('非自然')) | (df['備註'].str.contains('無接水電'))| (df['備註'].str.contains('損壞')) | df['備註'].str.contains('破損')) | (df['備註'].str.contains('滲*水')) | (df['備註'].str.contains('壁癌')) | (df['備註'].str.contains('屋況不佳')) | (df['備註'].str.contains('屋況*差')) | (df['備註'].str.contains('屋況嚴重瑕疵'))]
# Out:
#   File "<ipython-input-62-de66df60b3ee>", line 1
#     df[(df['備註'].str.contains('瑕疵物件')) | (df['備註'].str.contains('受損房屋')) | (df['備註'].str.contains('老舊')) | (df['備註'].str.contains('凶宅')) | (df['備註'].str.contains('祭祀公業')) | (df['備註'].str.contains('事故')) | (df['備註'].str.contains('非自然')) | (df['備註'].str.contains('無接水電'))| (df['備註'].str.contains('損壞')) | df['備註'].str.contains('破損')) | (df['備註'].str.contains('滲*水')) | (df['備註'].str.contains('壁癌')) | (df['備註'].str.contains('屋況不佳')) | (df['備註'].str.contains('屋況*差')) | (df['備註'].str.contains('屋況嚴重瑕疵'))]
#                                                                                                                                                                                                                                                                                                                                           ^
# SyntaxError: invalid syntax

# %%
df[df['備註'].str.contains('屋況嚴重瑕疵')]
# Out:
#            id 鄉鎮市區       交易標的        土地區段位置/建物區段門牌  土地移轉總面積(平方公尺) 使用分區或編定  \
# 45830  866681  潭子區  房地(土地+建物)  臺中市潭子區中山路一段121~150號          11.44       住
#
#       非都市土地使用分區 非都市土地使用地    交易年月日  交易筆棟數_土地  ...  flag_debt_relation  \
# 45830       NaN      NaN  1070214         1  ...                   f
#
#        flag_rush  flag_top_addition  flag_balcony_addition flag_flaw  \
# 45830          f                  f                      f         f
#
#       flag_presale flag_relative_relation  flag_multiple_obligee  selected  \
# 45830            f                      f                      f         f
#
#        flag_military_house
# 45830                    f
#
# [1 rows x 65 columns]

# %%
u_group2_1 = df[(df['備註'].str.contains('瑕疵物件')) | (df['備註'].str.contains('受損房屋')) | (df['備註'].str.contains('老舊')) | (df['備註'].str.contains('凶宅')) | (df['備註'].str.contains('祭祀公業')) | (df['備註'].str.contains('事故')) | (df['備註'].str.contains('非自然'))]

# %%
u_group2_2 = df[(df['備註'].str.contains('無接水電')) | (df['備註'].str.contains('損壞')) | (df['備註'].str.contains('破損')) | (df['備註'].str.contains('滲*水')) | (df['備註'].str.contains('壁癌')) | (df['備註'].str.contains('屋況不佳')) | (df['備註'].str.contains('屋況*差')) | (df['備註'].str.contains('屋況嚴重瑕疵')) | (df['備註'].str.contains('房屋*半毀')) | (df['備註'].str.contains('房屋破舊')) | (df['備註'].str.contains('屋況需整理')) | (df['備註'].str.contains('屋況殘破')) | (df['備註'].str.contains('屋況不良')) | (df['備註'].str.contains('房屋*已坍塌'))]

# %%
u_group_2_3 = df[(df['備註'].str.contains('臨近殯儀館')) | (df['備註'].str.contains('房屋老舊')) | (df['備註'].str.contains('建物須整修')) | (df['備註'].str.contains('入口處狹小巷弄狹小')) | (df['備註'].str.contains('無接水接電')) | (df['備註'].str.contains('高壓電線正下方')) | (df['備註'].str.contains('多年無人使用')) | (df['備註'].str.contains('建物已毀損'))]

# %%
u_group2_4 = df[(df['備註'].str.contains('壁癌')) | (df['備註'].str.contains('屋況不佳')) | (df['備註'].str.contains('屋況*差')) | (df['備註'].str.contains('死亡')) | (df['備註'].str.contains('年久失修')) | (df['備註'].str.contains('房屋破舊')) | (df['備註'].str.contains('廢墟')) | (df['備註'].str.contains('面積流失')) | (df['備註'].str.contains('荒廢')) | (df['備註'].str.contains('河床侵蝕')) | (df['備註'].str.contains('無法居住'))]

# %%
group2 = (u_group2_1 |  u_group2_2 | u_group_2_3 | u_group_4[])
# Out:
#   File "<ipython-input-80-1e5107c24a75>", line 1
#     group2 = (u_group2_1 |  u_group2_2[] | u_group_2_3[] | u_group_4[])
#                                        ^
# SyntaxError: invalid syntax

# %%
group2 = pd.concat([u_group2_1,u_group2_2,u_group_2_3,u_group2_4])

# %%
group4 = df[(df['備註'].str.contains('定著物')) | (df['備註'].str.contains('地上物'))]

# %%
re = group4[group4['交易標的']=='房地(土地+建物)']

# %%
re['備註'].value_counts()
# Out:
# 本買賣案件包含地上物(未保存登記之建物)交易價格。                               2
# 建物總價含雞舍畜牧場水權及地上設施設備地上物等賣渡在內                             1
# 包括地上物雞舍、倉儲設施及發電室                                        1
# 地上物無所有權人(平房)                                            1
# 地上物房舍無償                                                 1
# 含增建或未登記建物。;(包含)公共設施保留地之交易。;地上物為鐵皮屋                      1
# 本買賣案件係屬三親等間特殊交易，其交易價格可能異於市場正常交易價格。本基地地上物共有三層，本次僅交易壹層    1
# 地上物係買地送屋不另計價                                            1
# 含增建或未登記建物。;權利人共兩人賣方保證本土地上全部地上物均為賣方所有，有權處分               1
# 連同107年9月26日收件彰資字第127550號地上物房屋一併出售總價3000萬元整。             1
# 地上物建物係室內水產養殖生產設施                                        1
# 毗鄰國有土地之使用權及地上物一併移轉,權利人共2位。                              1
# 地上物為鐵架構造，地上物不計價。                                        1
# 包含未保存登記部分，所有地上物。                                        1
# 佔用部分水利地之使用權及地上物一併移轉                                     1
# Name: 備註, dtype: int64

# %%
group4['備註'].value_counts()
# Out:
# (包含)公共設施保留地之交易。;                      4078
# (包含)公共設施保留地之交易。                        481
# 公共設施保留地之交易。                            282
# (包含)公共設施保留地之交易。;本案係屬於協議價購案件            140
# 親友、員工或其他特殊關係間之交易。;(包含)公共設施保留地之交易。;     130
#                                       ...
# 本案買賣價含地上物                                1
# 公共設施保留地每坪8萬元工業區每坪15萬7000元                1
# 地上物:未辦保存建物一棟                             1
# 本件買賣包含地上設施及農作物。本件土地為袋地，出入須經他人土地通行。       1
# (包含)公共設施保留地之交易。;移轉費用賣方負擔                 1
# Name: 備註, Length: 1462, dtype: int64

# %%
y = group4[group4['交易標的']=='房地(土地+建物)']

# %%
y
# Out:
#              id 鄉鎮市區       交易標的          土地區段位置/建物區段門牌  土地移轉總面積(平方公尺) 使用分區或編定  \
# 1897     606071  魚池鄉  房地(土地+建物)         南投縣魚池鄉香茶巷1~30號        9174.38     NaN
# 3530    1966392  竹山鎮  房地(土地+建物)        南投縣竹山鎮民生巷61~90號         116.90     NaN
# 7633    2200895  南投市  房地(土地+建物)       南投縣南投市工業北二路1~30號        1629.00     NaN
# 8303    2256468  中寮鄉  房地(土地+建物)       南投縣中寮鄉永安街91~120號         140.86       住
# 8416    2256580  竹山鎮  房地(土地+建物)        南投縣竹山鎮育英路61~90號          85.00       住
# ...         ...  ...        ...                    ...            ...     ...
# 463830  2318145  鳥松區  房地(土地+建物)         高雄市鳥松區本?路1~30號          40.67       住
# 463958  2318275  三民區  房地(土地+建物)     高雄市三民區黃興路353巷1~30號          26.70       住
# 464343  2318678  前金區  房地(土地+建物)   高雄市前金區成功一路274巷31~60號          33.00       商
# 465159  2319516  三民區  房地(土地+建物)  高雄市三民區建國一路402巷9弄1~30號         191.41       住
# 466392  2320809  鳳山區  房地(土地+建物)     高雄市鳳山區南正二路51巷1~30號          25.10       住
#
# ...

# %%
y['備註'].value_counts()
# Out:
# (包含)公共設施保留地之交易。;                                        134
# 含增建或未登記建物。;(包含)公共設施保留地之交易。;                              49
# 親友、員工或其他特殊關係間之交易。;(包含)公共設施保留地之交易。;                       26
# (包含)公共設施保留地之交易。                                          20
# 本建物有電梯設施                                                 14
#                                                        ...
# 本買賣案件係屬三親等間特殊交易，其交易價格可能異於市場正常交易價格。本基地地上物共有三層，本次僅交易壹層      1
# 增建三樓四樓鐵皮屋                                                 1
# 門窗，內部設施全部毀損，不堪使用                                          1
# 包含地上全部畜牧設施                                                1
# 權利人共2人,含公共設施及未登記建物。                                       1
# Name: 備註, Length: 262, dtype: int64

# %%
y.to_excel('test.xlsx')

# %%
u_group2_1 = df[(df['備註'].str.contains('瑕疵物件')) | (df['備註'].str.contains('受損房屋')) | (df['備註'].str.contains('老舊')) | (df['備註'].str.contains('凶宅')) | (df['備註'].str.contains('祭祀公業')) | (df['備註'].str.contains('事故')) | (df['備註'].str.contains('非自然'))]

u_group2_2 = df[(df['備註'].str.contains('無接水電')) | (df['備註'].str.contains('損壞')) | (df['備註'].str.contains('破損')) | (df['備註'].str.contains('滲*水')) | (df['備註'].str.contains('壁癌')) | (df['備註'].str.contains('屋況不佳')) | (df['備註'].str.contains('屋況*差')) | (df['備註'].str.contains('屋況嚴重瑕疵')) | (df['備註'].str.contains('房屋*半毀')) | (df['備註'].str.contains('房屋破舊')) | (df['備註'].str.contains('屋況需整理')) | (df['備註'].str.contains('屋況殘破')) | (df['備註'].str.contains('屋況不良')) | (df['備註'].str.contains('房屋*已坍塌'))]

u_group_2_3 = df[(df['備註'].str.contains('臨近殯儀館')) | (df['備註'].str.contains('房屋老舊')) | (df['備註'].str.contains('建物須整修')) | (df['備註'].str.contains('入口處狹小巷弄狹小')) | (df['備註'].str.contains('無接水接電')) | (df['備註'].str.contains('高壓電線正下方')) | (df['備註'].str.contains('多年無人使用')) | (df['備註'].str.contains('建物已毀損'))]

u_group2_4 = df[(df['備註'].str.contains('壁癌')) | (df['備註'].str.contains('屋況不佳')) | (df['備註'].str.contains('屋況*差')) | (df['備註'].str.contains('死亡')) | (df['備註'].str.contains('年久失修')) | (df['備註'].str.contains('房屋破舊')) | (df['備註'].str.contains('廢墟')) | (df['備註'].str.contains('面積流失')) | (df['備註'].str.contains('荒廢')) | (df['備註'].str.contains('河床侵蝕')) | (df['備註'].str.contains('無法居住'))]

group2 = pd.concat([u_group2_1,u_group2_2,u_group_2_3,u_group2_4])

group2.index.duplicated(False)

group2 = group2.drop_duplicates()

# %%
for i in range(1,50):
# Out:
#              id 鄉鎮市區       交易標的           土地區段位置/建物區段門牌  土地移轉總面積(平方公尺)  \
# 294      604290  國姓鄉  房地(土地+建物)          南投縣國姓鄉東門巷1~30號          90.87
# 975      605092  南投市  房地(土地+建物)     南投縣南投市信義街250巷31~60號           5.41
# 1408     605569  水里鄉  房地(土地+建物)     南投縣水里鄉水信路一段631~660號          88.58
# 2186     606371  南投市         建物         南投縣南投市龍井街31~60號           0.00
# 2285     606474  名間鄉  房地(土地+建物)       南投縣名間鄉彰南路331~360號         107.63
# ...         ...  ...        ...                     ...            ...
# 424617  1975566  林園區  房地(土地+建物)  高雄市林園區東林西路364巷58弄1~30號          52.00
# 428287  1993227  新興區  房地(土地+建物)         高雄市新興區中正三路1~30號           8.21
# 428374  1993318  三民區  房地(土地+建物)         高雄市三民區北平二街1~30號          16.56
# 453498  2206252  林園區  房地(土地+建物)  高雄市林園區港嘴二路135巷18弄1~30號         109.00
# 456311  2209051  小港區         土地            鳳林段391~420地號          67.00
#
#        使用分區或編定 非都市土地使用分區 非都市土地使用地    交易年月日  交易筆棟數_土地  ...  flag_debt_relation  \
# ...
