# %%
check='Y'
while check =='Y':
    print('1.如果學校實施遠距教學，你會怎麼解決餓肚子的問題?')
    print('--------------------')
    print('  A.出門吃飯')
    print('  B.按宿舍的投幣機買泡麵吃')
    print('  C.睡覺就不會肚子餓了')
    score = 0
    wrong_answer = 1
    answer = str(input('請輸入選項答案_A_B_C:'))
    while wrong_answer == 1:
        if (answer =='A' or answer =='B' or answer == 'C'):
            if answer == 'A':
                score = score + 1
                wrong_answer = 0
            elif answer == 'B':
                score = score + 2
                wrong_answer = 0
            elif answer =='C':
                score = score + 3
                wrong_answer = 0
        else:
            print('請輸入A或B或C')
            answer = str(input('請輸入選項答案_A_B_C:'))
    print('2.今天政大天氣真好，而你剛好有閒暇時間，請問你會做甚麼呢?')
    print('--------------------')
    print('  A.在圖書館寫玥慧老師的程設作業')
    print('  B.出門排隊買口罩')
    print('  C.在宿舍追新番')
    wrong_answer = 1
    answer = str(input('請輸入選項答案_A_B_C:'))
    while wrong_answer == 1:
        if (answer =='A' or answer =='B' or answer == 'C'):
            if answer == 'A':
                score = score + 2
                wrong_answer = 0
            elif answer == 'B':
                score = score + 1
                wrong_answer = 0
            elif answer =='C':
                score = score + 3
                wrong_answer = 0
        else:
            print('請輸入A或B或C')
            answer = str(input('請輸入選項答案_A_B_C:'))
    print('3.你在床上睡個午覺，結果起床時發現已經上課了，你會怎麼做？')
    print('--------------------')
    print('  A.立馬狂奔到教室')
    print('  B.先慢慢打扮再走到教室')
    print('  C.不管了我要繼續睡')
    wrong_answer = 1
    answer = str(input('請輸入選項答案_A_B_C:'))
    while wrong_answer == 1:
        if (answer =='A' or answer =='B' or answer == 'C'):
            if answer == 'A':
                score = score + 1
                wrong_answer = 0
            elif answer == 'B':
                score = score + 2
                wrong_answer = 0
            elif answer =='C':
                score = score + 3
                wrong_answer = 0
        else:
            print('請輸入A或B或C')
            answer = str(input('請輸入選項答案_A_B_C:'))
    print('4.當你回宿舍發現你雨傘不見了，你會怎麼做？')
    print('--------------------')
    print('  A.立馬跑到去過的地方調閱監視器')
    print('  B.去seven買新的雨傘')
    print('  C.不見就算了，我要待在宿舍！')
    wrong_answer = 1
    answer = str(input('請輸入選項答案_A_B_C:'))
    while wrong_answer == 1:
        if (answer =='A' or answer =='B' or answer == 'C'):
            if answer == 'A':
                score = score + 1
                wrong_answer = 0
            elif answer == 'B':
                score = score + 2
                wrong_answer = 0
            elif answer =='C':
                score = score + 3
                wrong_answer = 0
        else:
            print('請輸入A或B或C')
            answer = str(input('請輸入選項答案_A_B_C:'))
    print('5.以下幾種政大小動物，你最喜歡的是？')
    print('--------------------')
    print('  A.花花 ')
    print('  B.台灣藍鵲')
    print('  C.穿山甲')
    wrong_answer = 1
    answer = str(input('請輸入選項答案_A_B_C:'))
    while wrong_answer == 1:
        if (answer =='A' or answer =='B' or answer == 'C'):
            if answer == 'A':
                score = score + 3
                wrong_answer = 0
            elif answer == 'B':
                score = score + 1
                wrong_answer = 0
            elif answer =='C':
                score = score + 2
                wrong_answer = 0
        else:
            print('請輸入A或B或C')
            answer = str(input('請輸入選項答案_A_B_C:'))

    if (score>=13 and score<=15):
        print('你是個缺乏安全感的人，不喜歡把自己的故事和別人一起分享，許多心事只願放在心裡，不願意與人交流，喜歡享受獨處的感覺。家是你唯一感到溫暖和安全的地方，在這個狹小的空間裡，你可以放鬆心情，為所欲為。宅在家裡，你喜歡上網，購物，讀書，沉浸在自己的世界裡，對外界不聞不問，你的「宅」功可謂是相當了得。')
    elif (score>=9 and score<=12):
        print('從小養尊處優、得到父母寵愛的你，不需要為了錢財而忙碌，到處奔波。因此，「宅」似乎就變成了你的一種習慣。由於家庭對你的保護過度，造成你與社會接觸得較少，使得你的溝通能力較弱，也不善於處理人際關係方面的問題。對你而言，只有家人才沒有陌生的感覺，其他人都很難走進你的內心，獲得你的信任。')
    elif (score>=5 and score<=8):
        print('你是個有理想、有抱負的人，有著美好的願望，對未來也有許多期許。只是，工作方面的小不如意，讓你的心情稍稍有些失落。但是，你宅在家裡，只是希望有個人的自由空間，做一些自己想做的事情，你很少在家玩樂，而是不斷地給自己的充電，學習一些新的技能，提高自己的能力和素質。因此，你屬於宅得比較充實的一類人。')
    check = input('是否要再測驗一次:(Y/N)')
    while (check !='Y'and check!='N'):
        print('請輸入Y或N')
        check = input('是否要再測驗一次:(Y/N)')
# Out:
# 1.如果學校實施遠距教學，你會怎麼解決餓肚子的問題?
# --------------------
#   A.出門吃飯
#   B.按宿舍的投幣機買泡麵吃
#   C.睡覺就不會肚子餓了
# 請輸入選項答案_A_B_C:A
# 2.今天政大天氣真好，而你剛好有閒暇時間，請問你會做甚麼呢?
# --------------------
#   A.在圖書館寫玥慧老師的程設作業
#   B.出門排隊買口罩
#   C.在宿舍追新番
# 請輸入選項答案_A_B_C:B
# 3.你在床上睡個午覺，結果起床時發現已經上課了，你會怎麼做？
# --------------------
#   A.立馬狂奔到教室
#   B.先慢慢打扮再走到教室
#   C.不管了我要繼續睡
# 請輸入選項答案_A_B_C:C
# 4.當你回宿舍發現你雨傘不見了，你會怎麼做？
# --------------------
#   A.立馬跑到去過的地方調閱監視器
#   B.去seven買新的雨傘
#   C.不見就算了，我要待在宿舍！
# 請輸入選項答案_A_B_C:A
# 5.以下幾種政大小動物，你最喜歡的是？
# --------------------
#   A.花花
#   B.台灣藍鵲
#   C.穿山甲
# 請輸入選項答案_A_B_C:B
# 你是個有理想、有抱負的人，有著美好的願望，對未來也有許多期許。只是，工作方面的小不如意，讓你的心情稍稍有些失落。但是，你宅在家裡，只是希望有個人的自由空間，做一些自己想做的事情，你很少在家玩樂，而是不斷地給自己的充電，學習一些新的技能，提高自己的能力和素質。因此，你屬於宅得比較充實的一類人。
# 是否要再測驗一次:(Y/N)N
